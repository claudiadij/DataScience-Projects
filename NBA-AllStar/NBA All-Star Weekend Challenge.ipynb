# %% [markdown]
# # NBA All-Star Weekend Challenge
#
# Your task...answer the following questions given the dataset given about the NBA All-Star Game from the year 2000 - 2016
#
# Become more familiar with the dataset <a href="https://www.kaggle.com/fmejia21/nba-all-star-game-20002016">here</a>
#
# Once completed, commit this notebook to github and submit the link to the google classroom assignment.
#
# <a href="https://classroom.google.com/u/2/c/NDc4MzEzMjI5Nzla/a/NTE3OTYxNzM2OTNa/details">Google Classroom</a>

# %%
import pandas as pd
import numpy as np

allstar = pd.read_csv('./NBA All Stars 2000-2016 - Sheet1.csv')
allstar
# Out:
#      Year           Player Pos    HT   WT                    Team  \
# 0    2016    Stephen Curry   G   6-3  190   Golden State Warriors
# 1    2016     James Harden  SG   6-5  220         Houston Rockets
# 2    2016     Kevin Durant  SF   6-9  240   Golden State Warriors
# 3    2016    Kawhi Leonard   F   6-7  230       San Antonio Spurs
# 4    2016    Anthony Davis  PF  6-11  253    New Orleans Pelicans
# ..    ...              ...  ..   ...  ...                     ...
# 434  2000  Antonio McDyess   F   6-9  245          Denver Nuggets
# 435  2000      Gary Payton   G   6-4  180     Seattle SuperSonics
# 436  2000  Rasheed Wallace  FC  6-11  230  Portland Trail Blazers
# 437  2000   David Robinson   C   7-1  250       San Antonio Spurs
# 438  2000      Vlade Divac   C   7-1  260        Sacramento Kings
#
#                              Selection Type    NBA Draft Status    Nationality
# 0       Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 7  United States
# ...

# %% [markdown]
# # What is the average weight of all players who played during this time?

# %%
allstar.describe(include = 'all')['WT']['mean']

print('The average weight of all players who played during this time was: 228.76')
# Out:
# The average weight of all players who played during this time was: 228.76

# %% [markdown]
# # What team is represented the most during this time?

# %%
allstar.groupby('Team').count().sort_values('Year',ascending=False)[['Year']].head()

print('Miami Heat was represented the most during this time.')
# Out:
# Miami Heat was represented the most during this time.

# %% [markdown]
# # What draft class is represeted the most during this time?

# %%
allstar.groupby('NBA Draft Status').count().sort_values('Player',ascending=False)[['Player']].head()

print('1996 Rnd 1 Pick 13 was represented the most during this time.')
# Out:
# 1996 Rnd 1 Pick 13 was represented the most during this time.

# %% [markdown]
# # Are foriegn players more prevalent in the All-Star Game during this time?

# %%
allstar.groupby('Nationality').count().sort_values('Player', ascending = False)[['Player']].head()

print('Foreign players are not more prevalent than American players.')
# Out:
# Foreign players are not more prevalent than American players.

# %% [markdown]
# # How often are the Western All-Stars voted in by fans?

# %%
allstar[allstar['Selection Type']=='Western All-Star Fan Vote Selection'].groupby('Year').count()[['Player']]

print('The Western All-Stars were voted in by fans every year.')
# Out:
# The Western All-Stars were voted in by fans every year.

# %% [markdown]
# # How many times does Steph Curry make the All-Star game during this time period?

# %%
allstar.groupby('Player').count().sort_values('Player', ascending = False)

print('Steph Curry makes the All-Star game four times.')
# Out:
# Steph Curry makes the All-Star game four times.

# %% [markdown]
# # How many Shooting Gaurds have made the All-Star game during this time?

# %%
allstar[allstar['Pos'] == 'SG'].count() # ans: 57

# Drop duplicates
allstar_nodups = allstar.drop_duplicates(['Player'])
allstar_nodups[allstar['Pos'] == 'SG'].count()

print('Before dropping duplicate players, 57 Shooting Guards have made the All-Star game, but after dropping duplicates, only 9 Shooting Guards have made the All-Star game during this time.')
# Out:
# Before dropping duplicate players, 57 Shooting Guards have made the All-Star game, but after dropping duplicates, only 9 Shooting Guards have made the All-Star game during this time.
# <ipython-input-29-10f7080593d8>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   allstar_nodups[allstar['Pos'] == 'SG'].count()

# %% [markdown]
# # How many Chicago Bulls players have made the All-Star Game during this time period?

# %%
allstar.groupby(['Team']).count() # ans: 12

# Drop duplicates
allstar_nodups.groupby(['Team']).count()

print('Before dropping duplicate players, 12 Chicago Bulls players have made the All-Star game, but after dropping duplicates, only 5 Chicago Bulls players have made the All-Star game during this time.')
# Out:
#                         Year  Player  Pos  HT  WT  Selection Type  \
# Team
# Atlanta Hawks              5       5    5   5   5               5
# Boston Celtics             6       6    6   6   6               6
# Brooklyn Nets              2       2    2   2   2               2
# Charlotte Bobcats          1       1    1   1   1               1
# Charlotte Hornets          1       1    1   1   1               1
# Chicago Bulls              5       5    5   5   5               5
# Cleveland Cavaliers        5       5    5   5   5               5
# Dallas Mavericks           4       4    4   4   4               4
# Denver Nuggets             2       2    2   2   2               2
# Detroit Pistons            5       5    5   5   5               5
# Golden State Warriors      5       5    5   5   5               5
# Houston Rockets            5       5    5   5   5               5
# Indiana Pacers             5       5    5   5   5               5
# ...
